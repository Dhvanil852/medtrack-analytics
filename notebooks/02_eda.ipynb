# %% [markdown]
# # 02. Exploratory Data Analysis
# Interactive charts to visualize the cleaned dataset demographics and correlations.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
import pandas as pd
import plotly.express as px
from src.preprocess import process_pipeline
from src.dataset_generator import generate_synthetic_data

df = process_pipeline(generate_synthetic_data(1000))

# %%
px.histogram(df, x='age', color='diagnosis', nbins=20, title='Age by Diagnosis').show()

# %%
px.box(df, x='diagnosis', y='bmi', color='diagnosis', title='BMI Distribution').show()
