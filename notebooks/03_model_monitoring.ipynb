# %% [markdown]
# # 03. Model Monitoring and Data Drift
# Simulating how model performance decays over time by calculating PSI and Accuracy on chunks.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
import pandas as pd
from src.preprocess import process_pipeline
from src.dataset_generator import generate_synthetic_data
from src.model_monitor import train_baseline_model, simulate_drift_over_time

df = process_pipeline(generate_synthetic_data(2000))

# %%
model, features, metrics = train_baseline_model(df)
print(f"Baseline Acc: {metrics[0]:.2f}, F1: {metrics[1]:.2f}")

# %%
drift_df = simulate_drift_over_time(df, model, features)
drift_df
