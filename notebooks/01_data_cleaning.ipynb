# %% [markdown]
# # 01. Data Cleaning Workflow
# This notebook demonstrates using our custom pipeline to clean the raw synthetic dataset.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
import pandas as pd
from src.dataset_generator import generate_synthetic_data
from src.preprocess import process_pipeline

# Ensure raw data exists (or generate it here)!
df_raw = generate_synthetic_data(1000)
df_raw.head()

# %%
# Run Pipeline
df_clean = process_pipeline(df_raw)
df_clean.head()

# %%
# Check for missing
df_clean.isnull().sum()
